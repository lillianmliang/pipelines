# %% [markdown]
# # Week 3 Assignment: Renters' Housing Burden in Sonoma County, CA
#
# In this week's assignment I mapped the ACS data for "Median Gross Rent as a Percentage of Household Income in the last 12 months (Dollars)."
#
# Author: Lillian Liang
#
# ## Data Summary
# This "Median Gross Rent as a Percentage of Household Income in the last 12 months (Dollars)" data fell under attribute B25071001 in Census Reporter. I attempted to plot the data at a block group scale for Sonoma County, CA for both 2019 (from Census Reporter) and 2015 (from NHGIS - IPUMS). I included the latter dataset because I struggled to use Census Reporter to get an older dataset. The latter dataset was in the form of a table (without geographies) so I attempted to join it to the geoJSON geometries from the 2019 dataset.

# %% [markdown]
# ## 2019 Data
#
# First, I imported the libraries and the 2019 dataset:

# %%
# first, import the libraries

# to read and visualize spatial data
import geopandas as gpd

# to provide basemaps 
import contextily as ctx

# to give more power to your figures (plots)
import matplotlib.pyplot as plt

# next, import the 2019 + JSON data
gdf_2019 = gpd.read_file('../Data/acs2019_5yr_B25071_15000US060971513081.geojson')

# %% [markdown]
# Next, I explored the dataset (similar to last week's HW) to figure out what each of the columns were and what I would be plotting.

# %%
# find the shape of the dataset 
gdf_2019.shape
# Out:
# (388, 5)

# %%
# Note there are 387-341 = 46 null entries for the data
gdf_2019.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   geoid             388 non-null    object
#  1   name              388 non-null    object
#  2   B25071001         342 non-null    float64
#  3   B25071001, Error  303 non-null    float64
#  4   geometry          388 non-null    geometry
# dtypes: float64(2), geometry(1), object(2)
# memory usage: 15.3+ KB

# %%
gdf_2019.head()
# Out:
#                  geoid                       name  B25071001  \
# 0         05000US06097          Sonoma County, CA       32.4
# 1  15000US060971501001  Block Group 1, Sonoma, CA       29.1
# 2  15000US060971501002  Block Group 2, Sonoma, CA       14.4
# 3  15000US060971501003  Block Group 3, Sonoma, CA       23.4
# 4  15000US060971502021  Block Group 1, Sonoma, CA       38.8
#
#    B25071001, Error                                           geometry
# 0               0.8  MULTIPOLYGON (((-122.93506 38.31395, -122.9350...
# 1              11.8  MULTIPOLYGON (((-122.46231 38.26304, -122.4623...
# 2              14.9  MULTIPOLYGON (((-122.53116 38.23141, -122.5310...
# 3              29.2  MULTIPOLYGON (((-122.45877 38.10383, -122.4586...
# 4              30.7  MULTIPOLYGON (((-122.45893 38.29226, -122.4589...

# %% [markdown]
# ## Cleaning & Plotting the 2019 Data
#
# I dropped the first row (total county data) and renamed the columns including the data to include the year (2019) so that I could differentiate it from the 2015 data.

# %%
# drop the row with index 0 (i.e. the first row)
gdf_2019 = gdf_2019.drop([0])

# %%
# plot it!
gdf_2019.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %%
# renaming the columns
list(gdf_2019)
# Out:
# ['geoid', 'name', '2019_B25071001', '2019_B25071001, Error', 'geometry']

# %%
gdf_2019.columns = ['geoid', 'name', '2019_B25071001', '2019_B25071001, Error', 'geometry']
gdf_2019.head()
# Out:
#                  geoid                       name  2019_B25071001  \
# 1  15000US060971501001  Block Group 1, Sonoma, CA            29.1
# 2  15000US060971501002  Block Group 2, Sonoma, CA            14.4
# 3  15000US060971501003  Block Group 3, Sonoma, CA            23.4
# 4  15000US060971502021  Block Group 1, Sonoma, CA            38.8
# 5  15000US060971502022  Block Group 2, Sonoma, CA            28.4
#
#    2019_B25071001, Error                                           geometry
# 1                   11.8  MULTIPOLYGON (((-122.46231 38.26304, -122.4623...
# 2                   14.9  MULTIPOLYGON (((-122.53116 38.23141, -122.5310...
# 3                   29.2  MULTIPOLYGON (((-122.45877 38.10383, -122.4586...
# 4                   30.7  MULTIPOLYGON (((-122.45893 38.29226, -122.4589...
# 5                    6.5  MULTIPOLYGON (((-122.47584 38.29376, -122.4758...

# %% [markdown]
# Now that the data's clean, I can plot a histogram of the metrics and map it!

# %%
# get some stats
gdf_2019['2019_B25071001'].describe()
# Out:
# count    341.000000
# mean      33.497361
# std        9.702251
# min        9.000000
# 25%       26.500000
# 50%       32.400000
# 75%       39.800000
# max       51.000000
# Name: 2019_B25071001, dtype: float64

# %%
# plot it as a historgram with 50 bins  & label the axis
gdf_2019['2019_B25071001'].plot.hist(bins=50)

plt.xlabel('Median Gross Rent as a Percentage of Household Income in the last 12 months (Dollars)')
# Out:
# Text(0.5, 0, 'Median Gross Rent as a Percentage of Household Income in the last 12 months (Dollars)')

# %%
# plot it on a map
gdf_2019.plot(figsize=(10,10),column='2019_B25071001',legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# __There are holes in this dataset__ - I am assuming those are the 46 null entries.

# %% [markdown]
# # 2nd Dataset - 2015 Data
#
# I imported the 2015 data and checked it out, similarly to the 2019 data. As previously mentiond, I knew this dataset lacked geometries, so I couldn't map it without merging it with 2019 data.

# %%
# next, import the 2015 data
gdf_2015 = gpd.read_file('../Data/nhgis0001_ds215_20155_2015_blck_grp.csv')

# %%
gdf_2015.shape
# Out:
# (23212, 41)

# %% [markdown]
# I found it had a lot more columns than the previous one, and the data types were all 'object' rather than float! I looked up some of the column names in the associated '.txt' file to find the relevant columns.

# %%
gdf_2015.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 23212 entries, 0 to 23211
# Data columns (total 41 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   GISJOIN    23212 non-null  object
#  1   YEAR       23212 non-null  object
#  2   REGIONA    23212 non-null  object
#  3   DIVISIONA  23212 non-null  object
#  4   STATE      23212 non-null  object
#  5   STATEA     23212 non-null  object
#  6   COUNTY     23212 non-null  object
#  7   COUNTYA    23212 non-null  object
#  8   COUSUBA    23212 non-null  object
#  9   PLACEA     23212 non-null  object
#  10  TRACTA     23212 non-null  object
#  11  BLKGRPA    23212 non-null  object
#  12  CONCITA    23212 non-null  object
#  13  AIANHHA    23212 non-null  object
#  14  RES_ONLYA  23212 non-null  object
#  15  TRUSTA     23212 non-null  object
#  16  AITSCEA    23212 non-null  object
#  17  ANRCA      23212 non-null  object
#  18  CBSAA      23212 non-null  object
#  19  CSAA       23212 non-null  object
#  20  METDIVA    23212 non-null  object
#  21  NECTAA     23212 non-null  object
#  22  CNECTAA    23212 non-null  object
#  23  NECTADIVA  23212 non-null  object
#  24  UAA        23212 non-null  object
#  25  CDCURRA    23212 non-null  object
#  26  SLDUA      23212 non-null  object
#  27  SLDLA      23212 non-null  object
#  28  ZCTA5A     23212 non-null  object
#  29  SUBMCDA    23212 non-null  object
#  30  SDELMA     23212 non-null  object
#  31  SDSECA     23212 non-null  object
#  32  SDUNIA     23212 non-null  object
#  33  PUMA5A     23212 non-null  object
#  34  BTTRA      23212 non-null  object
#  35  BTBGA      23212 non-null  object
#  36  NAME_E     23212 non-null  object
#  37  ADRRE001   23212 non-null  object
#  38  NAME_M     23212 non-null  object
#  39  ADRRM001   23212 non-null  object
#  40  geometry   0 non-null      geometry
# dtypes: geometry(1), object(40)
# memory usage: 7.3+ MB

# %%
list(gdf_2015)
# Out:
# ['GISJOIN',
#  'YEAR',
#  'REGIONA',
#  'DIVISIONA',
#  'STATE',
#  'STATEA',
#  'COUNTY',
#  'COUNTYA',
#  'COUSUBA',
#  'PLACEA',
#  'TRACTA',
#  'BLKGRPA',
#  'CONCITA',
#  'AIANHHA',
#  'RES_ONLYA',
#  'TRUSTA',
#  'AITSCEA',
#  'ANRCA',
#  'CBSAA',
#  'CSAA',
#  'METDIVA',
#  'NECTAA',
#  'CNECTAA',
#  'NECTADIVA',
#  'UAA',
#  'CDCURRA',
#  'SLDUA',
#  'SLDLA',
#  'ZCTA5A',
#  'SUBMCDA',
#  'SDELMA',
#  'SDSECA',
#  'SDUNIA',
#  'PUMA5A',
#  'BTTRA',
#  'BTBGA',
#  'NAME_E',
#  'ADRRE001',
#  'NAME_M',
#  'ADRRM001',
#  'geometry']

# %%
gdf_2015.head()
# Out:
#            GISJOIN       YEAR REGIONA DIVISIONA       STATE STATEA  \
# 0  G06000104001001  2011-2015                    California     06
# 1  G06000104002001  2011-2015                    California     06
# 2  G06000104002002  2011-2015                    California     06
# 3  G06000104003001  2011-2015                    California     06
# 4  G06000104003002  2011-2015                    California     06
#
#            COUNTY COUNTYA COUSUBA PLACEA  ... SDSECA SDUNIA PUMA5A BTTRA  \
# 0  Alameda County     001                 ...
# 1  Alameda County     001                 ...
# 2  Alameda County     001                 ...
# 3  Alameda County     001                 ...
# 4  Alameda County     001                 ...
#
#   BTBGA                                             NAME_E ADRRE001  \
# 0        Block Group 1, Census Tract 4001, Alameda Coun...     16.2
# 1        Block Group 1, Census Tract 4002, Alameda Coun...     19.5
# 2        Block Group 2, Census Tract 4002, Alameda Coun...     18.0
# 3        Block Group 1, Census Tract 4003, Alameda Coun...     21.7
# 4        Block Group 2, Census Tract 4003, Alameda Coun...     26.8
#
#                                               NAME_M ADRRM001 geometry
# 0  Block Group 1, Census Tract 4001, Alameda Coun...      4.1     None
# 1  Block Group 1, Census Tract 4002, Alameda Coun...     10.0     None
# 2  Block Group 2, Census Tract 4002, Alameda Coun...      1.9     None
# 3  Block Group 1, Census Tract 4003, Alameda Coun...      2.5     None
# 4  Block Group 2, Census Tract 4003, Alameda Coun...      6.6     None
#
# [5 rows x 41 columns]

# %% [markdown]
# ## Cleaning the 2015 Data
#
# I reduced the columns and renamed a few to be similar to the 2019 dataset to reduce confusion. I also filtered the data for only block groups in Sonoma County.

# %%
# reduce the columns

columns_to_keep = ['GISJOIN',
                   'YEAR',
                   'REGIONA',
                   'DIVISIONA',
                   'STATE',
                   'STATEA',
                   'COUNTY',
                   'COUNTYA',
                   'TRACTA',
                   'NAME_E',
                   'ADRRE001',
                   'ADRRM001',
                   'geometry']

gdf_2015 = gdf_2015[columns_to_keep]

# %%
# rename the relevant columns
gdf_2015.columns=['geoid', # changed
 'YEAR',
 'REGIONA',
 'DIVISIONA',
 'STATE',
 'STATEA',
 'COUNTY',
 'COUNTYA',
 'TRACTA',
 'NAME_E',
 '2015_B25071001', # changed
 '2015_B25071001, Error', # changed
 'geometry']

gdf_2015.head()
# Out:
#              geoid       YEAR REGIONA DIVISIONA       STATE STATEA  \
# 0  G06000104001001  2011-2015                    California     06
# 1  G06000104002001  2011-2015                    California     06
# 2  G06000104002002  2011-2015                    California     06
# 3  G06000104003001  2011-2015                    California     06
# 4  G06000104003002  2011-2015                    California     06
#
#            COUNTY COUNTYA  TRACTA  \
# 0  Alameda County     001  400100
# 1  Alameda County     001  400200
# 2  Alameda County     001  400200
# 3  Alameda County     001  400300
# 4  Alameda County     001  400300
#
#                                               NAME_E 2015_B25071001  \
# 0  Block Group 1, Census Tract 4001, Alameda Coun...           16.2
# 1  Block Group 1, Census Tract 4002, Alameda Coun...           19.5
# 2  Block Group 2, Census Tract 4002, Alameda Coun...           18.0
# 3  Block Group 1, Census Tract 4003, Alameda Coun...           21.7
# 4  Block Group 2, Census Tract 4003, Alameda Coun...           26.8
#
#   2015_B25071001, Error geometry
# 0                   4.1     None
# 1                  10.0     None
# 2                   1.9     None
# 3                   2.5     None
# 4                   6.6     None

# %%
# filter the rows for Sonoma county only
gdf_2015 = gdf_2015[gdf_2015['COUNTYA']=='097']

# confirm that it has the same number of rows as the other dataset - yay!
gdf_2015.shape
# Out:
# (387, 13)

# %% [markdown]
# ## Additionally clean the 2015 data to prepare for merge
#
# I knew that I wanted to merge the data with the other 2019 data but that I needed a common 'attribute' by which to merge. So, I modified the 'geoid' column in the 2015 dataset to match that of the 2019 dataset.

# %%
# to match the geoid column in 'gdf_2019', write a function that replaces leading 'G' with '15000US'

# also noticed extra leading 0's in county code and tract code
def clean(initial):    
    cleaned = initial[1:3] + initial[4:7] + initial[8:] # remove the leading G and extra 0's
    cleaned = '15000US'+ cleaned
    return cleaned

# apply the function to the column
gdf_2015['geoid'] = gdf_2015['geoid'].apply(clean)

gdf_2015
# Out:
#                      geoid       YEAR REGIONA DIVISIONA       STATE STATEA  \
# 21480  15000US060971501001  2011-2015                    California     06
# 21481  15000US060971501002  2011-2015                    California     06
# 21482  15000US060971501003  2011-2015                    California     06
# 21483  15000US060971502021  2011-2015                    California     06
# 21484  15000US060971502022  2011-2015                    California     06
# ...                    ...        ...     ...       ...         ...    ...
# 21862  15000US060971543032  2011-2015                    California     06
# 21863  15000US060971543041  2011-2015                    California     06
# 21864  15000US060971543042  2011-2015                    California     06
# 21865  15000US060971543043  2011-2015                    California     06
# 21866  15000US060979901000  2011-2015                    California     06
#
#               COUNTY COUNTYA  TRACTA  \
# 21480  Sonoma County     097  150100
# 21481  Sonoma County     097  150100
# 21482  Sonoma County     097  150100
# 21483  Sonoma County     097  150202
# 21484  Sonoma County     097  150202
# ...              ...     ...     ...
# 21862  Sonoma County     097  154303
# 21863  Sonoma County     097  154304
# 21864  Sonoma County     097  154304
# 21865  Sonoma County     097  154304
# 21866  Sonoma County     097  990100
#
#                                                   NAME_E 2015_B25071001  \
# 21480  Block Group 1, Census Tract 1501, Sonoma Count...           50.0
# 21481  Block Group 2, Census Tract 1501, Sonoma Count...           20.9
# 21482  Block Group 3, Census Tract 1501, Sonoma Count...           24.0
# 21483  Block Group 1, Census Tract 1502.02, Sonoma Co...           36.6
# 21484  Block Group 2, Census Tract 1502.02, Sonoma Co...           40.4
# ...                                                  ...            ...
# 21862  Block Group 2, Census Tract 1543.03, Sonoma Co...           33.8
# 21863  Block Group 1, Census Tract 1543.04, Sonoma Co...           36.3
# 21864  Block Group 2, Census Tract 1543.04, Sonoma Co...           30.0
# 21865  Block Group 3, Census Tract 1543.04, Sonoma Co...           30.8
# 21866  Block Group 0, Census Tract 9901, Sonoma Count...
#
#       2015_B25071001, Error geometry            geoid_new
# 21480                           None  15000US060971501001
# 21481                  11.4     None  15000US060971501002
# 21482                  42.9     None  15000US060971501003
# 21483                  21.4     None  15000US060971502021
# 21484                  22.9     None  15000US060971502022
# ...                     ...      ...                  ...
# 21862                  18.4     None  15000US060971543032
# 21863                  17.4     None  15000US060971543041
# 21864                  24.8     None  15000US060971543042
# 21865                  19.9     None  15000US060971543043
# 21866                           None  15000US060979901000
#
# [387 rows x 14 columns]

# %%
# further filter the dataset so that the merged dataset is minimal
# rename the relevant columns
columns_to_keep =['geoid',
 '2015_B25071001',
 '2015_B25071001, Error']
gdf_2015 = gdf_2015[columns_to_keep]

# %%
# the data is in string form rather than float, so we need to convert

gdf_2015['2015_B25071001'] = gdf_2015['2015_B25071001'].astype(float)
#gdf_2015.iloc[:,1] = gdf_2015.iloc[:,1].astype(float)

gdf_2015.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_57/1309837215.py in <module>
#       1 # the data is in string form rather than float, so we need to convert
#       2
# ----> 3 gdf_2015['2015_B25071001'] = gdf_2015['2015_B25071001'].astype(float)
#       4 #gdf_2015.iloc[:,1] = gdf_2015.iloc[:,1].astype(float)
#       5
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     590         values = self.values
#     591
# --> 592         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     593
#     594         new_values = maybe_coerce_values(new_values)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1199     if copy or is_object_dtype(arr.dtype) or is_object_dtype(dtype):
#    1200         # Explicit copy, or required since NumPy can't view from / to object.
# -> 1201         return arr.astype(dtype, copy=True)
#    1202
#    1203     return arr.astype(dtype, copy=copy)
#
# ValueError: could not convert string to float: ''

# %% [markdown]
# I struggled to figure out how to properly convert the string to a float in time to submit this assignment. It's a problem for next time!

# %% [markdown]
# ## Use merge to join the datasets
#
# I followed this documentation (https://geopandas.org/docs/user_guide/mergingdata.html) to merge the two datasets.

# %%
gdf_merged = gdf_2019.merge(gdf_2015, on='geoid')

# %%
gdf_merged.head()
# Out:
#                  geoid                       name  2019_B25071001  \
# 0  15000US060971501001  Block Group 1, Sonoma, CA            29.1
# 1  15000US060971501002  Block Group 2, Sonoma, CA            14.4
# 2  15000US060971501003  Block Group 3, Sonoma, CA            23.4
# 3  15000US060971502021  Block Group 1, Sonoma, CA            38.8
# 4  15000US060971502022  Block Group 2, Sonoma, CA            28.4
#
#    2019_B25071001, Error                                           geometry  \
# 0                   11.8  MULTIPOLYGON (((-122.46231 38.26304, -122.4623...
# 1                   14.9  MULTIPOLYGON (((-122.53116 38.23141, -122.5310...
# 2                   29.2  MULTIPOLYGON (((-122.45877 38.10383, -122.4586...
# 3                   30.7  MULTIPOLYGON (((-122.45893 38.29226, -122.4589...
# 4                    6.5  MULTIPOLYGON (((-122.47584 38.29376, -122.4758...
#
#   2015_B25071001 2015_B25071001, Error
# 0           50.0
# 1           20.9                  11.4
# 2           24.0                  42.9
# 3           36.6                  21.4
# 4           40.4                  22.9

# %% [markdown]
# In exploring the shape of the new merged dataset, it looked like the merge was a success.

# %%
gdf_merged.shape
# Out:
# (387, 7)

# %%
gdf_merged.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 387 entries, 0 to 386
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   geoid                  387 non-null    object
#  1   name                   387 non-null    object
#  2   2019_B25071001         341 non-null    float64
#  3   2019_B25071001, Error  302 non-null    float64
#  4   geometry               387 non-null    geometry
#  5   2015_B25071001         387 non-null    object
#  6   2015_B25071001, Error  387 non-null    object
# dtypes: float64(2), geometry(1), object(4)
# memory usage: 24.2+ KB

# %% [markdown]
# However, because the 2015 data was still an object/string, the data could not be graphed or plotted cleanly.

# %%
# plot it as a historgram with 50 bins
gdf_merged['2015_B25071001'].describe()

# %%
# plot it as a historgram with 50 bins
gdf_merged['2015_B25071001'].plot.hist(bins=50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/2770136371.py in <module>
#       1 # plot it as a historgram with 50 bins
# ----> 2 gdf_merged['2015_B25071001'].plot.hist(bins=50)
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwargs)
#    1311             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1312         """
# -> 1313         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1314
#    1315     def kde(self, bw_method=None, ind=None, **kwargs):
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     284     def generate(self):
#     285         self._args_adjust()
# --> 286         self._compute_plot_data()
#     287         self._setup_subplots()
#     288         self._make_plot()
#
# /opt/conda/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     451         # no non-numeric frames or series allowed
#     452         if is_empty:
# --> 453             raise TypeError("no numeric data to plot")
#     454
#     455         self.data = numeric_data.apply(self._convert_to_ndarray)
#
# TypeError: no numeric data to plot

# %%
# plot it on a map
gdf_merged.plot(figsize=(10,10),column='2015_B25071001',legend=True)
# Out:
# <AxesSubplot:>
